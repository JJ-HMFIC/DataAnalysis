# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
mpg = pd.read_csv('mpg.csv')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.loc[1:15:2]
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 11         audi  a4 quattro    2.8  1999    6    auto(l5)   4   15   25  p
# 13         audi  a4 quattro    3.1  2008    6    auto(s6)   4   17   25  p
# 15         audi  a6 quattro    2.8  1999    6    auto(l5)   4   15   24  p
#
#    category
# 1   compact
# 3   compact
# 5   compact
# 7   compact
# 9   compact
# 11  compact
# 13  compact
# 15  midsize

# %%
mpg.iloc[10:25:2, 2:7:2]
#loc는 안됌
# Out:
#     displ  cyl drv
# 10    2.0    4   4
# 12    2.8    6   4
# 14    3.1    6   4
# 16    3.1    6   4
# 18    5.3    8   r
# 20    5.3    8   r
# 22    6.0    8   r
# 24    5.7    8   r

# %%
var = [ 'model', 'hwy', 'cty']

# %%
mpg.loc[100:120:2,var]
# Out:
#        model  hwy  cty
# 100    civic   32   24
# 102    civic   29   23
# 104    civic   34   26
# 106    civic   36   24
# 108   sonata   26   18
# 110   sonata   30   21
# 112   sonata   26   18
# 114   sonata   28   19
# 116  tiburon   29   19
# 118  tiburon   27   20
# 120  tiburon   24   16

# %%
ex_range = list(range(100, 198, 4))

# %%
ex_range
# Out:
# [100,
#  104,
#  108,
#  112,
#  116,
#  120,
#  124,
#  128,
#  132,
#  136,
#  140,
#  144,
#  148,
#  152,
#  156,
#  160,
#  164,
#  168,
#  172,
#  176,
#  180,
#  184,
#  188,
#  192,
#  196]

# %%
mpg.loc[ex_range]
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 100        honda               civic    1.6  1999    4    auto(l4)   f   24
# 104        honda               civic    1.8  2008    4  manual(m5)   f   26
# 108      hyundai              sonata    2.4  1999    4    auto(l4)   f   18
# 112      hyundai              sonata    2.5  1999    6    auto(l4)   f   18
# 116      hyundai             tiburon    2.0  1999    4  manual(m5)   f   19
# 120      hyundai             tiburon    2.7  2008    6  manual(m6)   f   16
# 124         jeep  grand cherokee 4wd    4.0  1999    6    auto(l4)   4   15
# 128         jeep  grand cherokee 4wd    5.7  2008    8    auto(l5)   4   13
# 132   land rover         range rover    4.4  2008    8    auto(s6)   4   12
# 136      lincoln       navigator 2wd    5.4  2008    8    auto(l6)   r   12
# 140      mercury     mountaineer 4wd    5.0  1999    8    auto(l4)   4   13
# ...

# %%
for_iloc = mpg.loc[ex_range]

# %%
for_iloc.iloc[2:15:3]
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 108      hyundai       sonata    2.4  1999    4    auto(l4)   f   18   26  r
# 120      hyundai      tiburon    2.7  2008    6  manual(m6)   f   16   24  r
# 132   land rover  range rover    4.4  2008    8    auto(s6)   4   12   18  r
# 144       nissan       altima    2.5  2008    4  manual(m6)   f   23   32  r
# 156      pontiac   grand prix    3.8  1999    6    auto(l4)   f   17   27  r
#
#        category
# 108     midsize
# 120  subcompact
# 132         suv
# 144     midsize
# 156     midsize

# %% [markdown]
# ### -------------------------------------------------------------------------

# %%
sns.boxplot(data=mpg,y='cty')
# Out:
# <AxesSubplot:ylabel='cty'>

# %%
qut25 = mpg['cty'].quantile(.25)
qut75 = mpg['cty'].quantile(.75)

# %%
display(qut25)
display(qut75)
# Out:
# 14.0
# 19.0

# %%
print(max(mpg['cty']))
# Out:
# 35

# %%
print(min(mpg['cty']))
# Out:
# 9

# %%
iqr = qut75 - qut25
iqr
# Out:
# 5.0

# %%
qut25 -1.5*iqr #하한
# Out:
# 6.5

# %%
qut75 + 1.5*iqr#상한
# Out:
# 26.5

# %%
mpg['cty'] = np.where((mpg['cty']<6.5)|(mpg['cty']>26.5),np.nan, mpg['cty'])

# %%
mpg['cty'].isna().sum()
# Out:
# 5

# %%
mpg.dropna(subset=['cty']).groupby('drv').agg(mean_cty=('cty','mean'))
# Out:
#       mean_cty
# drv
# 4    14.330097
# f    19.445545
# r    14.080000

# %%
mpg.sort_values('cty')
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 126         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4  9.0
# 54         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4  9.0
# 59         dodge          durango 4wd    4.7  2008    8    auto(l5)   4  9.0
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4  9.0
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4  9.0
# ..           ...                  ...    ...   ...  ...         ...  ..  ...
# 99         honda                civic    1.6  1999    4  manual(m5)   f  NaN
# 196       toyota              corolla    1.8  2008    4  manual(m5)   f  NaN
# 212   volkswagen                jetta    1.9  1999    4  manual(m5)   f  NaN
# 221   volkswagen           new beetle    1.9  1999    4  manual(m5)   f  NaN
# 222   volkswagen           new beetle    1.9  1999    4    auto(l4)   f  NaN
#
#      hwy fl    category
# ...
